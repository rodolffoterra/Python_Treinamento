# %% [markdown]
# <strong><b><font size="5">Análise Estatística e Modelagem Preditiva de Séries Temporais - Em Python</font></b></strong>

# %% [markdown]
# <strong><b><font size="5">Aula 22 - Aplicando Inteligência Artificial Para Prever a Média Mensal de Vendas</font></b></strong>

# %% [markdown]
# Na aula anterior criamos nosso primeiro modelo de Deep Learning para a Previsão da Média Mensal de Vendas. Agora vamos trabalhar na otimização do modelo e começaremos com um modelo Stacked LSTM.
#
# **Deep Learning - Modelo Stacked LSTM**
#
# O Modelo Stacked LSTM nada mais é do que um Modelo com mais de uma camada LSTM. A camada LSTM é o diferencial do modelo e adicionando mais uma camada esperamos aumentar o poder de acurácia do modelo final.
#
# Nesta aula vamos discutir ainda como calcular o número de neurônios em cada camada.
#
# Esta aula considera algu conhecimento em Deep Learning e esse conhecimento pode ser obtido no material gratuito fornecido pela DSA, o <a href="http://www.deeplearningbook.com.br/">Deep Learning Book</a>. Lá você encontra alguns capítulos inteiros dedicados às LSTMs. Recomendamos a leitura antes de prosseguir nesta aula.
#
# **No Google Colab, altere seu Runtime para executar o treinamento usando GPU**.

# %% [markdown]
# Carregando os Pacotes Usados Neste Jupyter Notebook

# %%
# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.

# !pip install -q -U watermark
# Out:
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\rodolfo\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
# The new versions of Pandas and Matplotlib bring several warning messages to the developer. Let's disable this.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# Imports for data manipulation
import numpy as np
import pandas as pd
import itertools
from pandas import Series
from pandas.tseries.offsets import DateOffset

# Imports for data Visualization
import matplotlib.pyplot as plt
import matplotlib as m
import seaborn as sns

# Imports for metrics and model performance
import sklearn
import keras
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers import LSTM
from keras.layers import Dropout
from keras import optimizers
import statsmodels
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.stats as sms
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller


# Imports for formatting graphics
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from matplotlib.pylab import rcParams 
rcParams['figure.figsize'] = 15,7
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
#Versions of packages used in this jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Scientist Rodolfo Terra" --iversions
# Out:
# Author: Data Scientist Rodolfo Terra
#
# matplotlib : 3.3.2
# sklearn    : 0.23.2
# statsmodels: 0.12.0
# keras      : 2.4.3
# sys        : 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# pandas     : 1.1.3
# numpy      : 1.19.2
# seaborn    : 0.11.0

# %% [markdown]
# ## Definição do Problema de Negócio
#
# A HappyMoonVC é uma Venture Capital (VC).
#
# Além do investimento no GoInRail (descrito nas aulas anteriores), a HappyMoonVC está analisando um outro negócio. Uma rede de varejo que poderá fornecer produtos para os clientes do GoInRail (drone elétrico para transporte de passageiros).
#
# Um monitor touch-screen dentro do GoInRail permitiria que o cliente fizesse a compra de produtos enquanto faz a viagem, com a opção de pegar o produto na estação que for descer ou então receber direto na residência (se acha que isso é futurista demais, saiba que já existe no metrô do Japão).
#
# Para decidir se o investimento vale a pena, a HappyMoonVC precisa prever o volume de vendas.
#
# Esse é nosso trabalho.

# %% [markdown]
# ### Conjunto de Dados
#
# Usaremos conjuntos de dados que está disponível publicamente no site do Tableau e que representa as vendas históricas da empresa na qual a HappyMoonVC pretende investir. Aqui o link do dataset (que está sendo fornecido para você):
#
# https://community.tableau.com/docs/DOC-1236
#
# De todos os dados disponíveis, nosso interesse é na categoria de produtos de tecnologia.

# %%
# Load the data
dados = pd.read_csv('https://raw.githubusercontent.com/dsacademybr/Datasets/master/dataset6.csv')

# %%
# shape
dados.shape
# Out:
# (9994, 21)

# %%
# Columns
dados.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Análise Exploratória

# %%
# View the data
dados.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
# 2       0.0    6.8714
#
# [3 rows x 21 columns]

# %%
# Statistical Summart
dados.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Chacking missing values - we have no missing values in the dataset
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
# Adjusting the column names so that they are all lowercrase
dados.columns = map(str.lower, dados.columns)

# %%
# We will replace the spaces and dashes in the columnb names with '-'
dados.columns = dados.columns.str.replace(" ", "_")
dados.columns = dados.columns.str.replace("-", "_")

# %%
# Checking out 
dados.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %% [markdown]
# Vamos separar os dados por categoria (Móveis, Tecnologia, Material de escritório).

# %%
# Separating data by category

df_tecnologia = dados.loc[dados['category'] == 'Technology']

# %% [markdown]
# Agora vamos preparar as séries temporais.

# %%
# Aggregating sales by order date
ts_tecnologia = df_tecnologia.groupby('order_date')['sales'].sum().reset_index()

# %%
# How is each dataset doing?
ts_tecnologia
# Out:
#      order_date     sales
# 0    2014-01-06  1147.940
# 1    2014-01-09    31.200
# 2    2014-01-13   646.740
# 3    2014-01-15   149.950
# 4    2014-01-16   124.200
# ..          ...       ...
# 819  2017-12-25   401.208
# 820  2017-12-27   164.388
# 821  2017-12-28    14.850
# 822  2017-12-29   302.376
# 823  2017-12-30    90.930
#
# [824 rows x 2 columns]

# %% [markdown]
# Vamos mover a data para o índice e assim criar a série temporal.

# %%
# Putting the date as an index
ts_tecnologia = ts_tecnologia.set_index('order_date')

# %%
# View the serie
ts_tecnologia
# Out:
#                sales
# order_date
# 2014-01-06  1147.940
# 2014-01-09    31.200
# 2014-01-13   646.740
# 2014-01-15   149.950
# 2014-01-16   124.200
# ...              ...
# 2017-12-25   401.208
# 2017-12-27   164.388
# 2017-12-28    14.850
# 2017-12-29   302.376
# 2017-12-30    90.930
#
# [824 rows x 1 columns]

# %% [markdown]
# Agora podemos conferir a performance de vendas ao longo do tempo.

# %%
# Sale of technology Products
vendas_tecnologia = ts_tecnologia[['sales']]
ax = vendas_tecnologia.plot(color = 'b', figsize = (18,6))
plt.xlabel("Data")
plt.ylabel('Vendas')
plt.title("Venda de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Vamos ajustar o indice do tipo Index para o tipo DateTimeIndex (o que caracteriza uma série temporal), pois faremos uma agregação pela média para analisar a venda média ao longo do tempo.

# %%
# Chaging the index type
vendas_tecnologia.index = pd.to_datetime(vendas_tecnologia.index)

# %%
# Checking the index type
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Checking the index type
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Checking the resulting type
type(media_vendas_tecnologia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9853686beaff> in <module>
#       1 # Checking the resulting type
# ----> 2 type(media_vendas_tecnologia)
#
# NameError: name 'media_vendas_tecnologia' is not defined

# %%
# Resampling data for monthly frequency
# Using the average value of daily sales - we define the month as an index
media_vendas_tecnologia = vendas_tecnologia['sales'].resample('MS').mean()

# %%
# Checking the data
media_vendas_tecnologia
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Average Sale of technology Products
media_vendas_tecnologia.plot(figsize = (18, 6), color = 'blue')
plt.xlabel("Data de Compra")
plt.ylabel('Vendas')
plt.title("Venda Média de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Agora, vamos decompor uma das séries para avaliar seus componentes.

# %%
# Decomposition of the average salers time series of technology products
decomposition = seasonal_decompose(media_vendas_tecnologia, period = 12)
rcParams['figure.figsize'] = 18, 12

# Components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot
plt.subplot(411)
plt.plot(media_vendas_tecnologia, label = 'Série Original')
plt.legend(loc = 'best')
plt.subplot(412)
plt.plot(trend, label = 'Tendência')
plt.legend(loc = 'best')
plt.subplot(413)
plt.plot(seasonal, label = 'Sazonalidade')
plt.legend(loc = 'best')
plt.subplot(414)
plt.plot(residual, label = 'Resíduos')
plt.legend(loc = 'best')
plt.tight_layout()

# %% [markdown]
# Vamos testar a estacionaridade.

# %%
# Function to test stationarity
def testa_estacionaridade(serie):
    
    # Calculates mobile statistics
    rolmean = serie.rolling(window = 12).mean()
    rolstd = serie.rolling(window = 12).std()

    # Plot of mobile statistics
    orig = plt.plot(serie, color = 'blue', label = 'Original')
    mean = plt.plot(rolmean, color = 'red', label = 'Média Móvel')
    std = plt.plot(rolstd, color = 'black', label = 'Desvio Padrão')
    plt.legend(loc = 'best')
    plt.title('Estatísticas Móveis - Média e Desvio Padrão')
    plt.show()
    
    # Dickey-Fuller test:
    # Print
    print('\nResultado do Teste Dickey-Fuller:\n')

    # Test
    dfteste = adfuller(serie, autolag = 'AIC')

    # Formatting the output
    dfsaida = pd.Series(dfteste[0:4], index = ['Estatística do Teste',
                                               'Valor-p',
                                               'Número de Lags Consideradas',
                                               'Número de Observações Usadas'])


    # Loop for each test output item
    for key, value in dfteste[4].items():
        dfsaida['Valor Crítico (%s)'%key] = value

    # Print
    print (dfsaida)
    
    # Test the valor-p
    print ('\nConclusão:')
    if dfsaida[1] > 0.05:
        print('\nO valor-p é maior que 0.05 e, portanto, não temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente não é estacionária.')
    else:
        print('\nO valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente é estacionária.')

# %%
# Chacks whether the series is stationary
testa_estacionaridade(media_vendas_tecnologia)
# Out:
# Resultado do Teste Dickey-Fuller:
#
# Estatística do Teste           -7.187969e+00
# Valor-p                         2.547334e-10
# Número de Lags Consideradas     0.000000e+00
# Número de Observações Usadas    4.700000e+01
# Valor Crítico (1%)             -3.577848e+00
# Valor Crítico (5%)             -2.925338e+00
# Valor Crítico (10%)            -2.600774e+00
# dtype: float64
#
# Conclusão:
#
# O valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.
# Essa série provavelmente é estacionária.

# %% [markdown]
# ### Dividindo os dados em Treino e Teste

# %% [markdown]
# Para a preparação dos dados, vamos alternar entre objetos NumPy e Pandas, usando o que cada um oferece de melhor. Fique atento a cada passo.

# %%
# Original Series
X = media_vendas_tecnologia

# %%
# The first 36 records in the series will be used as training data
X[:-12]
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# Freq: MS, Name: sales, dtype: float64

# %%
# The last 12 records in the series will be used as test data
X[-12:]
# Out:
# order_date
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Devision in training and testing
treino, teste = np.array(X[:-12]), np.array(X[-12:])

# %%
# Adjust the shape, because now we don't have a pd.Serie, 
#but Numpy array, which is needed to train the LSTM model
trainset = treino.reshape(-1,1)
testset = teste.reshape(-1,1)

# %%
len(trainset)
# Out:
# 36

# %%
trainset
# Out:
# array([[ 449.04142857],
#        [ 229.78714286],
#        [2031.948375  ],
#        [ 613.02893333],
#        [ 564.69858824],
#        [ 766.90590909],
#        [ 533.60893333],
#        [ 708.43538462],
#        [2035.83813333],
#        [ 596.9009    ],
#        [1208.05632   ],
#        [1160.73288889],
#        [ 925.0708    ],
#        [ 431.12125   ],
#        [ 574.66233333],
#        [ 697.5595    ],
#        [ 831.64285714],
#        [ 429.0244    ],
#        [ 691.39773333],
#        [1108.90228571],
#        [ 950.8564    ],
#        [ 594.71611111],
#        [1037.98265217],
#        [1619.63763636],
#        [ 374.67106667],
#        [1225.8914    ],
#        [1135.15010526],
#        [ 875.91188235],
#        [1601.81616667],
#        [1023.2595    ],
#        [ 829.3125    ],
#        [ 483.6201    ],
#        [1144.1703    ],
#        [1970.835875  ],
#        [1085.64236   ],
#        [ 970.55486957]])

# %%
len(testset)
# Out:
# 12

# %%
testset
# Out:
# array([[1195.21807143],
#        [ 430.50171429],
#        [1392.85925   ],
#        [ 825.55913333],
#        [ 678.3294    ],
#        [ 853.055     ],
#        [1054.99663636],
#        [ 978.84233333],
#        [1077.70412   ],
#        [1493.43922727],
#        [1996.75092   ],
#        [ 955.86565217]])

# %% [markdown]
# ### Função Para o Cálculo da Acurácia

# %%
# Function
def performance(y_true, y_pred): 
    mse = ((y_pred - y_true) ** 2).mean()
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return( print('MSE das previsões é {}'.format(round(mse, 2))+
                  '\nRMSE das previsões é {}'.format(round(np.sqrt(mse), 2))+
                  '\nMAPE das previsões é {}'.format(round(mape, 2))))

# %% [markdown]
# ## Modelo LSTM
#
# A rede Long Short-Term Memory, ou LSTM, é uma rede neural recorrente treinada usando Backpropagation Through Time e supera o problema da dissipação do gradiente (isso é explicado no Deep Learning Book).
#
# Como tal, o modelo pode ser usado para criar grandes redes recorrentes que, por sua vez, podem ser usadas para resolver problemas de sequência difíceis no aprendizado de máquina e obter resultados de última geração.
#
# Podemos alterar a arquitetura do modelo e adicionar mais uma camada LSTM, aumentando assim a capacidade de previsão do modelo.
#
# Esse modelo é estudado em detalhes no curso <a href="https://www.datascienceacademy.com.br/course?courseid=deep-learning-ii">Deep Learning II</a>.

# %% [markdown]
# ### Como Escolher o Número de Camadas e Neurônios em Uma Rede Neural Artificial?
#
# Toda Rede Neural Artificial tem três tipos de camadas: entrada, oculta e saída.
#
# Portanto, criar a arquitetura da rede significa criar valores para o número de camadas de cada tipo e o número de nós em cada uma dessas camadas.
#
# **A Camada de Entrada**
#
# Toda rede neural, sem exceção, deve ter uma camada de entrada, aquela que recebe os dados.
#
# Com relação ao número de neurônios que compõem essa camada, esse parâmetro é determinado de maneira completa e exclusiva quando você conhece o formato dos dados de treinamento. Especificamente, o número de neurônios que compõem essa camada é igual ao número de recursos (colunas) em seus dados. Algumas configurações de redes neurais adicionam um nó adicional para um termo de polarização (bias).
#
# **A Camada de Saída**
#
# Como a camada de entrada, toda rede neural tem exatamente uma camada de saída. Determinar seu tamanho (número de neurônios) é simples; é completamente determinado pela configuração do modelo escolhido.
#
# Estamos trabalhando em um problema de regressão ou classificação?
#
# Se a rede neural for um regressor, a camada de saída terá um único nó para retornar um valor numérico.
#
# Se a rede neural for um classificador, ela também terá um único nó, a menos que o softmax seja usado. Nesse caso, a camada de saída possui um nó por rótulo de classe no seu modelo, que em geral entrega uma probabilidade para cada classe.
#
# **As Camadas Ocultas**
#
# Definir as camadas de entrada e saída é fácil, pois elas estão associadas aos dados que alimentamos na rede e ao que vamos obter como saída, respectivamente. Resta então as camadas ocultas.
#
# Quantas camadas ocultas? Bem, se seus dados são linearmente separáveis (que você já sabe quando começa a codificar uma rede neural), não precisa de nenhuma camada oculta.
#
# Existe um consenso sobre a diferença de desempenho da inclusão de camadas ocultas adicionais: as situações em que o desempenho melhora com uma segunda (ou terceira, etc.) camada oculta são muito poucas. Uma camada oculta é suficiente para a grande maioria dos problemas.
#
# E quanto ao tamanho da (s) camada (s) oculta (s) - quantos neurônios? Existem algumas regras práticas derivadas empiricamente, dentre as quais a mais comum é a de que "o tamanho ideal da camada oculta geralmente está entre o tamanho da entrada e o tamanho das camadas de saída".
#
# **Boas Práticas**
#
# Em suma, para a maioria dos problemas, é possível obter um desempenho decente (mesmo sem uma segunda etapa de otimização) definindo a configuração da camada oculta usando apenas duas regras: (i) o número de camadas ocultas é igual a um; e (ii) o número de neurônios nessa camada é a média dos neurônios nas camadas de entrada e saída.
#
# Portanto, há realmente duas decisões que devem ser tomadas com relação às camadas ocultas: quantas camadas ocultas devem realmente existir na rede neural e quantos neurônios estarão em cada uma dessas camadas.
#
# Problemas que requerem duas camadas ocultas raramente são encontrados. No entanto, redes neurais com duas camadas ocultas podem representar funções com qualquer tipo de forma. Atualmente, não há razão teórica para usar redes neurais com mais de duas camadas ocultas. De fato, para muitos problemas práticos, não há razão para usar mais de uma camada oculta. Assim, o useo de muitas camadas ocultas pode tornar o treinamento muito mais lento e oferecer quase nada em termos de performance da rede. Mesmo modelos avançados de Deep Learning (com muitas camadas ocultas) são problemas e dados bem específicos.
#
# Decidir o número de neurônios nas camadas ocultas é uma parte muito importante para decidir sua arquitetura geral da rede neural. Embora essas camadas não interajam diretamente com o ambiente externo, elas exercem uma tremenda influência sobre o resultado final. Tanto o número de camadas ocultas quanto o número de neurônios em cada uma dessas camadas ocultas devem ser cuidadosamente considerados.
#
# Usar poucos neurônios nas camadas ocultas resultará em algo chamado desajustamento. A falta de ajuste ocorre quando há  poucos neurônios nas camadas ocultas para detectar adequadamente os sinais em um conjunto de dados complicado.
#
# O uso de muitos neurônios nas camadas ocultas pode resultar em vários problemas. Primeiro, muitos neurônios nas camadas ocultas podem resultar em sobreajuste (overfitting). O sobreajuste ocorre quando a rede neural tem tanta capacidade de processamento de informações que a quantidade limitada de informações contidas no conjunto de treinamento não é suficiente para treinar todos os neurônios nas camadas ocultas. Um segundo problema pode ocorrer mesmo quando os dados de treinamento são suficientes. Um número excessivamente grande de neurônios nas camadas ocultas pode aumentar o tempo necessário para treinar a rede. A quantidade de tempo de treinamento pode aumentar a ponto de ser impossível treinar adequadamente a rede neural.
#
# Existem muitos métodos práticos para determinar o número correto de neurônios a serem usados nas camadas ocultas, como os seguintes:
#
# - O número de neurônios ocultos deve estar entre o tamanho da camada de entrada e o tamanho da camada de saída.
# - O número de neurônios ocultos deve ser 2/3 do tamanho da camada de entrada, mais o tamanho da camada de saída.
# - O número de neurônios ocultos deve ser menor que o dobro do tamanho da camada de entrada.
#
# Mas na prática, o ideal é a experimentação e testar diferentes combinações do número de camadas e neurônios.
#
# ### Preparando os Dados Para Treinamento
#
#
# Como regra geral, sempre que você usa uma rede neural, você deve normalizar ou dimensionar seus dados. Usaremos a classe MinMaxScaler da biblioteca sklearn.preprocessing para dimensionar nossos dados entre 0 e 1. O parâmetro feature_range é usado para especificar o intervalo dos dados dimensionados e se não for especificado o intevalo será entre 0 e 1.

# %%
# Create the scaler
scaler = MinMaxScaler()

# %%
# train this scaler in the training data (never in the fill dataset or test data)
scaler.fit(trainset)
# Out:
# MinMaxScaler()

# %%
# Apply the same scaler to training data
# (We don't need to apply it to the test data, as we will convert the forecast output before evaluating the model)
trainset = scaler.transform(trainset)

# %%
trainset.shape
# Out:
# (36, 1)

# %%
trainset
# Out:
# array([[0.12139983],
#        [0.        ],
#        [0.99784626],
#        [0.21219877],
#        [0.18543853],
#        [0.29739956],
#        [0.16822437],
#        [0.26502477],
#        [1.        ],
#        [0.20326877],
#        [0.54166199],
#        [0.51545928],
#        [0.38497454],
#        [0.11147753],
#        [0.1909554 ],
#        [0.25900285],
#        [0.33324403],
#        [0.11031652],
#        [0.25559112],
#        [0.48676098],
#        [0.39925188],
#        [0.20205906],
#        [0.44749318],
#        [0.76955219],
#        [0.08022139],
#        [0.55153717],
#        [0.50129424],
#        [0.35775554],
#        [0.75968454],
#        [0.43934106],
#        [0.33195373],
#        [0.14054584],
#        [0.50628867],
#        [0.96400863],
#        [0.47388209],
#        [0.41015881]])

# %% [markdown]
# Aqui definimos os hiperparâmetros.

# %%
# Number of repetitions
n_rep = 20

#Number of epochs
num_epochs = 200

# Number of input (we will use 12 series to predict the next 12 series)
n_input = 12

# Length of output strings (in number of timesteps)
n_output = 12

# Here we are indicating that our series is univariate, therefore, only 1 resource
n_features = 1

# Number of time series samples in each batrch
size_batch = 10

# %% [markdown]
# O TimeseriesGenerator do Keras transforma automaticamente um conjunto de dados univariado de séries temporais em um dataset para problema de aprendizado supervisionado.
#
# https://keras.io/preprocessing/sequence/

# %%
# Generator
generator = TimeseriesGenerator(trainset, 
                               trainset,
                               length = n_output,
                               batch_size = size_batch)

# %% [markdown]
# Podemos agora criar o modelo Stacked LSTM.
#
# Detalhes sobre os hiperparâmetros aqui:
#
# https://keras.io/layers/recurrent/

# %%
# Creation and training of the Standard LSTM model

# We created a matrix filled with zeros that will receive the result of our model's predictions
resultado = np.zeros((n_input, n_rep))

# Loop
# We will repeat the training process 20 times and store all the results, so that we will use
# different samples. At the end, we take the average to find the predictions.
for i in range(n_rep):
    

    # The first step is to create the model, that is, an object of the Sequential () class of Keras
    modelo_lstm = Sequential()
    
    # We can now add the first layer of the network, or input layer.
    # This is the layer that recives the data.
    # As we are going to create a stacked LSTM layer architecture, we need to add the paramenter:
    # return_sequence = True, indicating that this layer must return a sequence that will be used
    # as input to the next LSTM layer
    modelo_lstm.add(LSTM(40, activation = 'tanh', return_sequences = True, input_shape = (n_input, n_features)))
    
    # another LSTM layer
    modelo_lstm.add(LSTM(40, activation = 'relu'))
    
    # We add the first intermediate or hidden layer
    modelo_lstm.add(Dense(50, activation = 'relu'))
    
    # We add second intermediate or hidden layer
    modelo_lstm.add(Dense(50, activation = 'relu'))
    
    # We added the output and all we need is 1 neuron as we are only value
    modelo_lstm.add(Dense(1))
    
    # With tha lçayers ready, we can define the loss function, in this case we will use the MSE (Mean Squared Error)
    # And we indicate the optimization algorithm (minimizing the loss funciton), in our case ADAM
    adam = optimizers.Adam(learning_rate = 0.001)
    modelo_lstm.compile(optimizer = adam, loss = 'mean_squared_error')
    
    # Here we do the training generating batches of data
    modelo_lstm.fit_generator(generator, epochs = num_epochs)
    
    # List for predictions
    pred_list = []
    
    # Generates a batch of data
    batch = trainset[-n_input:].reshape((1, n_input, n_features))
    
    # Loop to make predictions
    for j in range(n_input):   
        pred_list.append(modelo_lstm.predict(batch)[0]) 
        batch = np.append(batch[:,1:,:], [[pred_list[j]]], axis = 1)
        
        # Generates the dataframe with predictions
    df_predict_modelo_lstm = pd.DataFrame(scaler.inverse_transform(pred_list),
                                      index = X[-n_input:].index, columns = ['Prediction'])

    resultado[:,i] = df_predict_modelo_lstm['Prediction']
    
print(resultado)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 4s 7ms/step - loss: 0.1973
# Epoch 2/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2060
# Epoch 3/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1911
# Epoch 4/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1038
# Epoch 5/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1271
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 7/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0552
# Epoch 8/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0591
# Epoch 9/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0670
# Epoch 10/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0597
# Epoch 11/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0509
# Epoch 12/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 13/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0415
# Epoch 14/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0400
# Epoch 15/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0395
# Epoch 16/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0405
# Epoch 17/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0432
# Epoch 18/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0559
# Epoch 19/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0517
# Epoch 20/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0491
# Epoch 21/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0520
# Epoch 22/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 23/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0515
# Epoch 24/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0557
# Epoch 25/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0550
# Epoch 26/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 27/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0442
# Epoch 28/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0559
# Epoch 29/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0445
# Epoch 30/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0525
# Epoch 31/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 32/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0440
# Epoch 33/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 34/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0550
# Epoch 35/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0542
# Epoch 36/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 37/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0509
# Epoch 38/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 39/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0473
# Epoch 40/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0519
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 42/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0479
# Epoch 43/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0442
# Epoch 44/200
# 3/3 [==============================] - ETA: 0s - loss: 0.065 - 0s 7ms/step - loss: 0.0527
# Epoch 45/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0526
# Epoch 46/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0492
# Epoch 47/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0449
# Epoch 48/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0430
# Epoch 49/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0476
# Epoch 50/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0431
# Epoch 51/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0527
# Epoch 52/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 53/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0541
# Epoch 54/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 55/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0457
# Epoch 56/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0514
# Epoch 57/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 58/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0429
# Epoch 59/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0566
# Epoch 60/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0445
# Epoch 61/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0438
# Epoch 62/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0558
# Epoch 63/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0467
# Epoch 64/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 65/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 66/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 67/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 68/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0448
# Epoch 69/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 70/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0555
# Epoch 71/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 72/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 73/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 74/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0511
# Epoch 75/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 76/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 77/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 78/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 79/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 80/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0453
# Epoch 81/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 82/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 83/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 84/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 85/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0442
# Epoch 86/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 87/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 88/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0451
# Epoch 89/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0442
# Epoch 90/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0437
# Epoch 91/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0556
# Epoch 92/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 94/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 95/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 96/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 97/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0422
# Epoch 98/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0411
# Epoch 99/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 100/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0529
# Epoch 101/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0530
# Epoch 102/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0484
# Epoch 103/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0545
# Epoch 104/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0468
# Epoch 105/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 106/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 107/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0428
# Epoch 108/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 109/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0560
# Epoch 110/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0461
# Epoch 111/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0455
# Epoch 112/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 113/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0544
# Epoch 114/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 115/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 116/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0433
# Epoch 117/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 118/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 119/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 120/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 121/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0526
# Epoch 122/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0474
# Epoch 123/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0450
# Epoch 124/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 125/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0448
# Epoch 126/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 127/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 128/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0525
# Epoch 129/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0455
# Epoch 130/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 131/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 132/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0464
# Epoch 133/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0450
# Epoch 134/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0551
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0456
# Epoch 136/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 137/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0478
# Epoch 138/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0431
# Epoch 139/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0525
# Epoch 140/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0459
# Epoch 141/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0458
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 143/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 144/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 145/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 146/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0552
# Epoch 147/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0548
# Epoch 148/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0483
# Epoch 149/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0554
# Epoch 150/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 151/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0422
# Epoch 153/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0431
# Epoch 154/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0526
# Epoch 155/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0520
# Epoch 156/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0539
# Epoch 157/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0487
# Epoch 158/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 159/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0475
# Epoch 160/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0525
# Epoch 161/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0430
# Epoch 162/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0429
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0434
# Epoch 164/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 165/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0461
# Epoch 166/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0454
# Epoch 167/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0550
# Epoch 168/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0472
# Epoch 169/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0514
# Epoch 170/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0486
# Epoch 171/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0440
# Epoch 172/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0478
# Epoch 173/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0558
# Epoch 174/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0456
# Epoch 175/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 176/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0490
# Epoch 177/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0518
# Epoch 178/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0452
# Epoch 179/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0480
# Epoch 180/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0556
# Epoch 181/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0453
# Epoch 182/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0483
# Epoch 183/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 184/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0519
# Epoch 185/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 186/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0461
# Epoch 187/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 188/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 189/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 190/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0443
# Epoch 191/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 192/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0428
# Epoch 193/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0523
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0455
# Epoch 195/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0450
# Epoch 196/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 197/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0453
# Epoch 198/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 199/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 200/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 1/200
# 3/3 [==============================] - 4s 8ms/step - loss: 0.2411
# Epoch 2/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1411
# Epoch 3/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1743
# Epoch 4/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1397
# Epoch 5/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1038
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0407
# Epoch 7/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 8/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0565
# Epoch 9/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0675
# Epoch 10/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0605
# Epoch 11/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 12/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0454
# Epoch 13/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 14/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0469
# Epoch 15/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0412
# Epoch 16/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 17/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0438
# Epoch 18/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0554
# Epoch 19/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 20/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 21/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0540
# Epoch 22/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0508
# Epoch 23/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 24/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 25/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 26/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0510
# Epoch 27/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0475
# Epoch 28/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 29/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 30/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0526
# Epoch 31/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 32/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0454
# Epoch 33/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 34/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0510
# Epoch 35/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0449
# Epoch 36/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 37/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0554
# Epoch 38/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0546
# Epoch 39/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0540
# Epoch 40/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0538
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 42/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 43/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 44/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0418
# Epoch 45/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 46/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 47/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0547
# Epoch 48/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 49/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0481
# Epoch 50/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0507
# Epoch 51/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0508
# Epoch 52/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 53/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0445
# Epoch 54/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0525
# Epoch 55/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 56/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 57/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 58/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 59/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 60/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0448
# Epoch 61/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0554
# Epoch 62/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 63/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0462
# Epoch 64/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0447
# Epoch 65/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 66/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0476
# Epoch 67/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 68/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0454
# Epoch 69/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0525
# Epoch 70/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 71/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0510
# Epoch 72/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0545
# Epoch 73/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0464
# Epoch 74/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 75/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 76/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0440
# Epoch 77/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0426
# Epoch 78/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0529
# Epoch 79/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 80/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0483
# Epoch 81/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 82/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 83/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0536
# Epoch 84/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0535
# Epoch 85/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0539
# Epoch 86/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 87/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 88/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 89/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0430
# Epoch 90/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0424
# Epoch 91/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0425
# Epoch 92/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0528
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0550
# Epoch 94/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 95/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 96/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0460
# Epoch 97/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 98/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0562
# Epoch 99/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 100/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0552
# Epoch 101/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0462
# Epoch 102/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 103/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0451
# Epoch 104/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0551
# Epoch 105/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0457
# Epoch 106/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 107/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 108/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 109/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0442
# Epoch 110/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0556
# Epoch 111/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0450
# Epoch 112/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0551
# Epoch 113/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0543
# Epoch 114/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0488
# Epoch 115/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0510
# Epoch 116/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 117/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0431
# Epoch 118/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0564
# Epoch 119/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0445
# Epoch 120/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 121/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 122/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0541
# Epoch 123/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0537
# Epoch 124/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 125/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0544
# Epoch 126/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 127/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0433
# Epoch 128/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 129/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 130/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 131/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 132/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0488
# Epoch 133/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0447
# Epoch 134/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0545
# Epoch 136/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 137/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0457
# Epoch 138/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0437
# Epoch 139/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 140/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 141/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 143/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0496
# Epoch 144/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 145/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 146/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0511
# Epoch 147/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 148/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0557
# Epoch 149/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0548
# Epoch 150/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 151/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0452
# Epoch 153/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0430
# Epoch 154/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 155/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0552
# Epoch 156/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 157/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0538
# Epoch 158/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 159/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0539
# Epoch 160/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 161/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 162/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0559
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0552
# Epoch 164/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0445
# Epoch 165/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0478
# Epoch 166/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 167/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0436
# Epoch 168/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0484
# Epoch 169/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0522
# Epoch 170/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 171/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0498
# Epoch 172/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0539
# Epoch 173/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 174/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0513
# Epoch 175/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0435
# Epoch 176/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0560
# Epoch 177/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 178/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 179/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 180/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 181/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0451
# Epoch 182/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0435
# Epoch 183/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0478
# Epoch 184/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0555
# Epoch 185/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 186/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0468
# Epoch 187/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 188/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0448
# Epoch 189/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 190/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 191/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0480
# Epoch 192/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 193/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 195/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 196/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0462
# Epoch 197/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 198/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 199/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 200/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 1/200
# 3/3 [==============================] - 4s 7ms/step - loss: 0.1583
# Epoch 2/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2178
# Epoch 3/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1962
# Epoch 4/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1396
# Epoch 5/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0857
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0623
# Epoch 7/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0408
# Epoch 8/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0649
# Epoch 9/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0702
# Epoch 10/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0598
# Epoch 11/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 12/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0441
# Epoch 13/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 14/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 15/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0552
# Epoch 16/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0536
# Epoch 17/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0528
# Epoch 18/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0551
# Epoch 19/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0503
# Epoch 20/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0493
# Epoch 21/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 22/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0445
# Epoch 23/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 24/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0437
# Epoch 25/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0480
# Epoch 26/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0557
# Epoch 27/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 28/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 29/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0543
# Epoch 30/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0540
# Epoch 31/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 32/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 33/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 34/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 35/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0426
# Epoch 36/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0561
# Epoch 37/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 38/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 39/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0474
# Epoch 40/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 42/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 43/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0437
# Epoch 44/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 45/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0448
# Epoch 46/200
# 3/3 [==============================] - ETA: 0s - loss: 0.035 - 0s 7ms/step - loss: 0.0440
# Epoch 47/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0436
# Epoch 48/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0484
# Epoch 49/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0525
# Epoch 50/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 51/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 52/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0540
# Epoch 53/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0459
# Epoch 54/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 55/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0428
# Epoch 56/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 57/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0423
# Epoch 58/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0482
# Epoch 59/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 60/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0526
# Epoch 61/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0497
# Epoch 62/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0492
# Epoch 63/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 64/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0482
# Epoch 65/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0435
# Epoch 66/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0433
# Epoch 67/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 68/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0457
# Epoch 69/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 70/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 71/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0459
# Epoch 72/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 73/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 74/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0546
# Epoch 75/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0542
# Epoch 76/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 77/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 78/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 79/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 80/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 81/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 82/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 83/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 84/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 85/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 86/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0520
# Epoch 87/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 88/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 89/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 90/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0478
# Epoch 91/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0424
# Epoch 92/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 94/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0453
# Epoch 95/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 96/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0491
# Epoch 97/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0447
# Epoch 98/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0520
# Epoch 99/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0520
# Epoch 100/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 101/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 102/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 103/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0484
# Epoch 104/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 105/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0434
# Epoch 106/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0428
# Epoch 107/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0423
# Epoch 108/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483
# Epoch 109/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0520
# Epoch 110/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0545
# Epoch 111/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 112/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 113/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 114/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0438
# Epoch 115/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 116/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0421
# Epoch 117/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0563
# Epoch 118/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 119/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0497
# Epoch 120/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0543
# Epoch 121/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0540
# Epoch 122/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 123/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0431
# Epoch 124/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0419
# Epoch 125/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0566
# Epoch 126/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 127/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0484
# Epoch 128/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 129/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 130/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0459
# Epoch 131/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 132/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0437
# Epoch 133/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0553
# Epoch 134/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0543
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 136/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0442
# Epoch 137/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0521
# Epoch 138/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0518
# Epoch 139/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0444
# Epoch 140/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 141/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0454
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 143/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0434
# Epoch 144/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 145/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 146/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 147/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0463
# Epoch 148/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 149/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0446
# Epoch 150/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 151/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0517
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0546
# Epoch 153/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 154/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 155/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 156/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 157/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0548
# Epoch 158/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0447
# Epoch 159/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0516
# Epoch 160/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 161/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0422
# Epoch 162/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0521
# Epoch 164/200
# 3/3 [==============================] - ETA: 0s - loss: 0.039 - 0s 7ms/step - loss: 0.0459
# Epoch 165/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0445
# Epoch 166/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 167/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0456
# Epoch 168/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 169/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0433
# Epoch 170/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 171/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0482
# Epoch 172/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 173/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 174/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0452
# Epoch 175/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 176/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 177/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0545
# Epoch 178/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0536
# Epoch 179/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0534
# Epoch 180/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 181/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 182/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 183/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0427
# Epoch 184/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0554
# Epoch 185/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 186/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0443
# Epoch 187/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 188/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0465
# Epoch 189/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0442
# Epoch 190/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0423
# Epoch 191/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0510
# Epoch 192/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0482
# Epoch 193/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0484
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0488
# Epoch 195/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0449
# Epoch 196/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 197/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 198/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 199/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0455
# Epoch 200/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 1/200
# 3/3 [==============================] - 4s 7ms/step - loss: 0.2318
# Epoch 2/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1415
# Epoch 3/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1761
# Epoch 4/200
# ...
# Epoch 44/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0511
# Epoch 45/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0546
# Epoch 46/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0543
# Epoch 47/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0542
# Epoch 48/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0454
# Epoch 49/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0558
# Epoch 50/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0434
# Epoch 51/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0528
# Epoch 52/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0514
# Epoch 53/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0448
# Epoch 54/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0439
# Epoch 55/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0479
# Epoch 56/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0514
# Epoch 57/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0527
# Epoch 58/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0472
# Epoch 59/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0547
# Epoch 60/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0484
# Epoch 61/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0438
# Epoch 62/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0423
# Epoch 63/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0418
# Epoch 64/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0422
# Epoch 65/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0435
# Epoch 66/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0532
# Epoch 67/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0502
# Epoch 68/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0514
# Epoch 69/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0492
# Epoch 70/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 71/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0443
# Epoch 72/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0560
# Epoch 73/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0441
# Epoch 74/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0433
# Epoch 75/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0427
# Epoch 76/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0478
# Epoch 77/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0441
# Epoch 78/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0516
# Epoch 79/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0474
# Epoch 80/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0547
# Epoch 81/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 82/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0473
# Epoch 83/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0521
# Epoch 84/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0475
# Epoch 85/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0423
# Epoch 86/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0569
# Epoch 87/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0515
# Epoch 88/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0526
# Epoch 89/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0470
# Epoch 90/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0511
# Epoch 91/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0521
# Epoch 92/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0548
# Epoch 93/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0545
# Epoch 94/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 95/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0555
# Epoch 96/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0439
# Epoch 97/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0475
# Epoch 98/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0424
# Epoch 99/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0425
# Epoch 100/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0529
# Epoch 101/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0550
# Epoch 102/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0494
# Epoch 103/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0512
# Epoch 104/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0510
# Epoch 105/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0453
# Epoch 106/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0475
# Epoch 107/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0564
# Epoch 108/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0438
# Epoch 109/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0477
# Epoch 110/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0526
# Epoch 111/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0487
# Epoch 112/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 113/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0460
# Epoch 114/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0441
# Epoch 115/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 116/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0526
# Epoch 117/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0515
# Epoch 118/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 119/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0456
# Epoch 120/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0513
# Epoch 121/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0521
# Epoch 122/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0450
# Epoch 123/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0523
# Epoch 124/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0480
# Epoch 125/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0514
# Epoch 126/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0523
# Epoch 127/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0513
# Epoch 128/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0487
# Epoch 129/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0480
# Epoch 130/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0431
# Epoch 131/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0517
# Epoch 132/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0442
# Epoch 133/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0444
# Epoch 134/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0552
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0472
# Epoch 136/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513
# Epoch 137/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 138/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0454
# Epoch 139/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0553
# Epoch 140/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 141/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0547
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0519
# Epoch 143/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 144/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0556
# Epoch 145/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0442
# Epoch 146/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 147/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0425
# Epoch 148/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0431
# Epoch 149/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0527
# Epoch 150/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0462
# Epoch 151/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0525
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0468
# Epoch 153/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0453
# Epoch 154/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0481
# Epoch 155/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0554
# Epoch 156/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0486
# Epoch 157/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0482
# Epoch 158/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0437
# Epoch 159/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0478
# Epoch 160/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0481
# Epoch 161/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0524
# Epoch 162/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0469
# Epoch 164/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0519
# Epoch 165/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0450
# Epoch 166/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0478
# Epoch 167/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0559
# Epoch 168/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0548
# Epoch 169/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 170/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0487
# Epoch 171/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0479
# Epoch 172/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0558
# Epoch 173/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0520
# Epoch 174/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0548
# Epoch 175/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0513
# Epoch 176/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0517
# Epoch 177/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 178/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0425
# Epoch 179/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0476
# Epoch 180/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 181/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0451
# Epoch 182/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0455
# Epoch 183/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0523
# Epoch 184/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0522
# Epoch 185/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0465
# Epoch 186/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0550
# Epoch 187/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0544
# Epoch 188/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 189/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0515
# Epoch 190/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0442
# Epoch 191/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0419
# Epoch 192/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0416
# Epoch 193/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0423
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0560
# Epoch 195/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 196/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0521
# Epoch 197/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0484
# Epoch 198/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 199/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0438
# Epoch 200/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0525
# [[1113.6270516  1087.32225813 1077.51069515 1039.74192612 1094.33160927
#   1127.70178521 1115.95749158 1061.26575714  998.71279099 1059.18802326
#   1094.62947413 1092.03798526 1066.63491388 1053.97598028 1109.05218322
#   1075.67861634 1128.38691744 1118.76858446 1104.39803133 1051.36985115]
#  [1148.40581506 1120.01957381 1124.68551327 1084.05769372 1134.33221177
#   1186.74221741 1151.34807829 1109.84733276 1116.56770009 1098.47878807
#   1129.71880504 1132.52898291 1099.1259202  1082.82091404 1146.55037642
#   1115.18667071 1143.5354501  1155.12548267 1147.60167682 1082.46373456]
#  [1148.18857932 1120.81633809 1122.54125229 1084.63485398 1132.11631036
#   1188.88680134 1152.69541352 1108.50500321 1113.3776288  1099.52610546
#   1128.65943096 1146.37652324 1096.46187588 1081.7230016  1145.97348528
#   1115.93079462 1147.21790804 1153.76447601 1149.27551156 1078.94188897]
#  [1152.12315129 1124.41574481 1124.29975298 1088.61846007 1134.39809298
#   1196.91332815 1157.39041821 1110.67359288 1113.53156691 1104.01033336
#   1131.60777635 1158.23998434 1097.0472713  1082.40877973 1150.11517397
#   1120.73759283 1147.21381738 1160.03750781 1153.12848556 1078.56140348]
#  [1164.67007606 1134.35244979 1135.90474877 1101.34349017 1147.8980346
#   1217.65923348 1169.564985   1120.76391302 1121.91796442 1110.85121377
#   1142.9483323  1168.80358343 1106.08908991 1089.38271435 1163.53265644
#   1132.29861399 1144.16336688 1165.17376587 1168.87247881 1086.3569693 ]
#  [1151.27057099 1120.64296933 1118.43977051 1080.47911709 1129.18491969
#   1199.98003365 1157.96989293 1104.87335561 1106.3114928  1095.01577267
#   1127.87902933 1157.76019262 1088.39449627 1074.02889499 1148.80120994
#   1116.55047625 1154.50757725 1154.07493581 1153.33560229 1068.01761181]
#  [1161.07965804 1126.86336075 1125.52463744 1086.69767847 1137.61249294
#   1216.12394304 1167.14395837 1111.07916059 1111.34430014 1103.28666277
#   1135.82487319 1163.95281059 1093.17233689 1076.7739452  1158.9420713
#   1127.64155557 1171.10727263 1175.6388661  1159.81542786 1071.45215404]
#  [1176.46539533 1137.4233536  1133.02933559 1098.17763991 1153.54960855
#   1237.0431633  1181.12519879 1114.54228363 1078.66205532 1114.47451857
#   1149.70643061 1176.55538992 1104.10334212 1083.91075279 1175.39116568
#   1141.87743977 1185.98167703 1190.10678777 1176.02995501 1080.696299  ]
#  [1201.26450185 1156.34966741 1164.66157179 1123.39555497 1183.46236684
#   1278.58621489 1204.70119706 1144.12870389 1141.11819118 1137.72121846
#   1174.02886724 1195.40118226 1125.75096952 1099.04243838 1202.36402902
#   1164.67954918 1160.3152423  1213.36371432 1210.97627419 1100.3686744 ]
#  [1198.00230571 1150.81650739 1160.02383638 1112.95198455 1179.6738746
#   1274.13115988 1201.19592942 1137.38847532 1135.70581336 1127.34089184
#   1169.11544266 1194.25967197 1119.6117993  1091.4915588  1197.80100203
#   1154.40746365 1156.45290283 1204.75157681 1209.2254704  1092.9914327 ]
#  [1168.9565527  1123.41536239 1125.12084594 1070.9701017  1142.54561729
#   1232.19809586 1174.92073943 1104.70300103 1106.02929087 1092.18411882
#   1137.76395513 1177.28514268 1085.94429675 1063.40388213 1165.25579442
#   1117.08010946 1166.863425   1172.71888622 1176.87015568 1058.74122597]
#  [1176.21274306 1127.93629861 1129.64673401 1073.88900508 1148.31054567
#   1247.4842578  1181.97024366 1108.1156905  1109.0545515  1096.19576749
#   1143.31767612 1184.98430879 1087.92062525 1064.36513413 1172.7713113
#   1123.31670206 1177.07415058 1181.37871226 1183.93957498 1059.39282553]]

# %% [markdown]
# O mais delicado na criação do modelo é definir o input_shape da primeira camada. É isso que o modelo espera como entrada para cada amostra em termos do número de etapas de tempo e do número de recursos.
#
# Estamos trabalhando com uma série univariada, portanto, o número de recursos é um, para uma variável.
#
# O número de etapas de tempo como entrada é o número que escolhemos para prever as sequências de saída. Em nosso exemplo, estamos usando 12 sequências para prever 12 sequências.
#
# Quase sempre temos várias amostras; portanto, o modelo espera que o componente de entrada dos dados de treinamento tenha as dimensões ou a forma:
#
# [samples, timesteps, features]
#
# Em nosso exemplo, nós temos:
#
# - samples = n_rep (20)
# - timesteps = n_input (12)
# - features = n_features (1)

# %%
# Let's create a matrix with the same dimensions as the result matrix used in the training
resultado_final = np.zeros((resultado.shape[0],1))

# %%
# Loop for generate the final forescast
for i in range(resultado.shape[0]):
    resultado_final[i] = np.mean(resultado[i,:])

# %%
# Final forescast
resultado_final
# Out:
# array([[1083.5145963 ],
#        [1125.45714689],
#        [1125.78065913],
#        [1129.27361172],
#        [1139.62738402],
#        [1125.37589609],
#        [1134.0538583 ],
#        [1144.44258962],
#        [1169.08400646],
#        [1163.36695498],
#        [1133.14852997],
#        [1138.86384292]])

# %%
# Adjust final
resultado_final = resultado_final.reshape((12,))

# %%
# Final forescast
resultado_final
# Out:
# array([1083.5145963 , 1125.45714689, 1125.78065913, 1129.27361172,
#        1139.62738402, 1125.37589609, 1134.0538583 , 1144.44258962,
#        1169.08400646, 1163.36695498, 1133.14852997, 1138.86384292])

# %%
# Calculate and prinbt model preformance
modelo_lstm_performance = performance(testset, resultado_final)
modelo_lstm_performance
# Out:
# MSE das previsões é 157634.37
# RMSE das previsões é 397.03
# MAPE das previsões é 36.61

# %% [markdown]
# Conseguimos reduzir o RMSE, mas aumentamos o MAPE.
#
# Não é fácil ajustar um modelo de previsão de série temporal. De fato, trouxemos uma série difícil mesmo (média mensal de vendas) para demonstrar as complicações envolvidas em todo o processo.
#
# Estamos procurando fazer poucas mudanças de uma aula para outra, para ajudar você a comparar os modelos. Mas fique à vontade para mudar os hiperparâmetros e tentar chegar ao melhor modelo.
#
# Vamos continuar em busca do modelo ideal para prever nossas vendas. Ainda tenho algumas cartas na manga. Como é mesmo que se diz? Ahh...sim: "quanto mais ferramentas você sabe, mais problemas é capaz de resolver".
#
# Abaixo o plot das previsões.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(media_vendas_tecnologia.index, 
         media_vendas_tecnologia.values,
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(media_vendas_tecnologia[36:].index, 
         resultado_final,
         label = 'Previsões Com Modelo LSTM Padrão', 
         color = 'Red')

plt.title('Previsões Com Modelo LSTM Padrão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# Vamos fazer o Forecasting para 12 meses de horizonte de previsão. A função DateOffset() vai nos ajudar a criar as datas.
#
# Vejamos qual é a última data da nossa série original:

# %%
# Last date of series
media_vendas_tecnologia.index[-1]
# Out:
# Timestamp('2017-12-01 00:00:00', freq='MS')

# %%
# Create a sequence of dates from the last date of our original series
datas_para_prever_forecasting = [media_vendas_tecnologia.index[-1] + DateOffset(months = x) for x in range(0, 13)]

# %%
#View
datas_para_prever_forecasting
# Out:
# [Timestamp('2017-12-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00')]

# %%
# Our original series is a pd.Series object
type(media_vendas_tecnologia)
# Out:
# pandas.core.series.Series

# %%
# Objects of type pd.Series give you more work to manipulate. We will convert the original series into a dataframe.
df_original = pd.DataFrame(media_vendas_tecnologia)

# %%
#View Data
df_original.head()
# Out:
#                   sales
# order_date
# 2014-01-01   449.041429
# 2014-02-01   229.787143
# 2014-03-01  2031.948375
# 2014-04-01   613.028933
# 2014-05-01   564.698588

# %%
# Let's now create a new dataframe
# The index (date) will be the sequence of future dates
# The data column name we extracted from the original series
# ATTENTION: We are not extracting the data from the original series, only the column name
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# View the data
# Did you understand why the NaN values? These are future dates, and we now need to include our forecasts.
data_futuras
# Out:
#            sales
# 2018-01-01   NaN
# 2018-02-01   NaN
# 2018-03-01   NaN
# 2018-04-01   NaN
# 2018-05-01   NaN
# 2018-06-01   NaN
# 2018-07-01   NaN
# 2018-08-01   NaN
# 2018-09-01   NaN
# 2018-10-01   NaN
# 2018-11-01   NaN
# 2018-12-01   NaN

# %%
# We use future dates to extract predictions from our model
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index = data_futuras[-n_input:].index, columns = ['Prediction'])

# %%
# We concatenate the original series with the forecasting values of 12 month in addition to the series
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# View the data
df_forecasting
# Out:
#                   sales   Prediction
# 2014-01-01   449.041429          NaN
# 2014-02-01   229.787143          NaN
# 2014-03-01  2031.948375          NaN
# 2014-04-01   613.028933          NaN
# 2014-05-01   564.698588          NaN
# 2014-06-01   766.905909          NaN
# 2014-07-01   533.608933          NaN
# 2014-08-01   708.435385          NaN
# 2014-09-01  2035.838133          NaN
# 2014-10-01   596.900900          NaN
# 2014-11-01  1208.056320          NaN
# 2014-12-01  1160.732889          NaN
# 2015-01-01   925.070800          NaN
# 2015-02-01   431.121250          NaN
# 2015-03-01   574.662333          NaN
# 2015-04-01   697.559500          NaN
# 2015-05-01   831.642857          NaN
# 2015-06-01   429.024400          NaN
# 2015-07-01   691.397733          NaN
# 2015-08-01  1108.902286          NaN
# 2015-09-01   950.856400          NaN
# 2015-10-01   594.716111          NaN
# 2015-11-01  1037.982652          NaN
# 2015-12-01  1619.637636          NaN
# 2016-01-01   374.671067          NaN
# 2016-02-01  1225.891400          NaN
# 2016-03-01  1135.150105          NaN
# 2016-04-01   875.911882          NaN
# 2016-05-01  1601.816167          NaN
# 2016-06-01  1023.259500          NaN
# 2016-07-01   829.312500          NaN
# 2016-08-01   483.620100          NaN
# 2016-09-01  1144.170300          NaN
# 2016-10-01  1970.835875          NaN
# 2016-11-01  1085.642360          NaN
# 2016-12-01   970.554870          NaN
# 2017-01-01  1195.218071          NaN
# 2017-02-01   430.501714          NaN
# 2017-03-01  1392.859250          NaN
# 2017-04-01   825.559133          NaN
# 2017-05-01   678.329400          NaN
# 2017-06-01   853.055000          NaN
# 2017-07-01  1054.996636          NaN
# 2017-08-01   978.842333          NaN
# 2017-09-01  1077.704120          NaN
# 2017-10-01  1493.439227          NaN
# 2017-11-01  1996.750920          NaN
# 2017-12-01   955.865652          NaN
# 2018-01-01          NaN  1051.369851
# 2018-02-01          NaN  1082.463735
# 2018-03-01          NaN  1078.941889
# 2018-04-01          NaN  1078.561403
# 2018-05-01          NaN  1086.356969
# 2018-06-01          NaN  1068.017612
# 2018-07-01          NaN  1071.452154
# 2018-08-01          NaN  1080.696299
# 2018-09-01          NaN  1100.368674
# 2018-10-01          NaN  1092.991433
# 2018-11-01          NaN  1058.741226
# 2018-12-01          NaN  1059.392826

# %% [markdown]
# ### Previsão x Forecasting
#
# Esse dataframe acima é para não restar qualquer dúvida do que estamos fazendo.
#
# Nas **previsões** do modelo, usamos os dados de teste, 12 meses que correspondem aos 12 últimos registros da série original (2017-01-01 a 2017-12-01. Fazemos isso para poder calcular a precisão do modelo, comparando as previsões com os valores reais. Esse é o padrão em Machine Learning.
#
# No **forecasting**, criamos 12 meses após a última data da série original. Obviamente, não temos dados históricos para esses meses e o que queremos é exatamente a previsão de vendas. O forecasting significa usar o modelo treinado e prever valores sobre novas datas.
#
# Bingo!
#
# Vamos colocar o forecasting em um Plot.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(df_forecasting.index, 
         df_forecasting['sales'],
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(df_forecasting.index, 
         df_forecasting['Prediction'],
         label = 'Forecasting Com Modelo Stacked LSTM', 
         color = 'Red')

plt.title('Forecasting Com Modelo LSTM Padrão Em Horizonte de 12 Meses de Previsão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# E aí está nosso primeiro modelo de Deep Learning para previsão de séries temporais!
#
# Como estamos até agora:
#
# - Aula 15 --> Modelo ARMA(1,1) - AIC = 550.3, RMSE = 420.2 e MAPE = 29.58
# - Aula 16 --> Modelo ARIMA(6,0,2) - AIC = 559.4, RMSE = 401.5 e MAPE = 26.58
# - Aula 17 --> Modelo SARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC = 176.74, RMSE = 425.89 e MAPE = 34.95
# - Aula 18 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) - AIC = 146.77, RMSE = 353.57 e MAPE = 30.55
# - Aula 19 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) com exog  - AIC = 149.66, RMSE = 341.23 e MAPE = 32.54
# - Aula 20 --> Modelo Prophet 1 - RMSE = 347.58 e MAPE = 28.53
# - Aula 21 --> Modelo Prophet 2 - RMSE = 325.52 e MAPE = 26.45
# - Aula 22 --> Modelo LSTM Padrão - RMSE = 397.12 e MAPE = 31.46
# - Aula 23 --> Modelo Stacked LSTM - RMSE = 396.24 e MAPE = 36.35
#
# Vamos seguir otimizando nossa rede LSTM e ver até onde conseguimos ir com essa arquitetura.
